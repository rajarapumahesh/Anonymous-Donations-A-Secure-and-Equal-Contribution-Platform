# %%
import uuid
import hashlib

# Generate a unique code for each donation request
def generate_donation_code():
    donation_id = str(uuid.uuid4())
    return donation_id

# Encrypt donor information
def encrypt_donor_info(donor_name, donor_account):
    # Use a secure encryption algorithm to encrypt the donor information
    encrypted_info = hashlib.sha256((donor_name + donor_account).encode()).hexdigest()
    return encrypted_info

# Simulate the donation process
def donate_to_collector(donation_code, donor_name, donor_account, amount):
    # Encrypt the donor information
    encrypted_info = encrypt_donor_info(donor_name, donor_account)

    # Simulate the donation process
    # Here, you could send the encrypted donor information and the donation amount to the collector's account
    # This step would involve integrating with a payment gateway or a financial transaction API

    # Print a confirmation message to demonstrate successful donation
    print(f"Donation of {amount} received for code: {donation_code}")
    print(f"Donor information: {encrypted_info}")

# Example usage
donation_code = generate_donation_code()
donor_name = "John Doe"
donor_account = "ABC123"
donation_amount = 100

donate_to_collector(donation_code, donor_name, donor_account, donation_amount)
# Out:
# Donation of 100 received for code: d10c8455-79ca-4680-b5af-11a03f438f88
# Donor information: 8749cd0b405f808a7aa0244eb58f51cd3e00c076aa8bf40cf68922f26b3681dd

# %%
import uuid
import hashlib

# Class to represent a Money Collector
class MoneyCollector:
    def __init__(self, collector_name, bank_account):
        self.collector_name = collector_name
        self.bank_account = bank_account

    def generate_donation_code(self):
        donation_id = str(uuid.uuid4())
        return donation_id


# Class to handle the donation process
class DonationProcessor:
    @staticmethod
    def encrypt_donor_info(donor_name, donor_account):
        # Use a secure encryption algorithm to encrypt the donor information
        encrypted_info = hashlib.sha256((donor_name + donor_account).encode()).hexdigest()
        return encrypted_info

    @staticmethod
    def donate_to_collector(collector, donation_code, donor_name, donor_account, amount):
        # Encrypt the donor information
        encrypted_info = DonationProcessor.encrypt_donor_info(donor_name, donor_account)

        # Simulate the donation process
        # Here, you could send the encrypted donor information and the donation amount to the collector's account
        # This step would involve integrating with a payment gateway or a financial transaction API

        # Print a confirmation message to demonstrate successful donation
        print(f"Donation of {amount} received for code: {donation_code}")
        print(f"Donor information: {encrypted_info}")
        print(f"Collector: {collector.collector_name}")
        print(f"Collector's Bank Account: {collector.bank_account}")


# Example usage
collector_name = "John Smith"
collector_bank_account = "XYZ789"
donation_amount = 100

collector = MoneyCollector(collector_name, collector_bank_account)
donation_code = collector.generate_donation_code()

donor_name = input("Enter your name: ")
donor_account = input("Enter your bank account: ")

DonationProcessor.donate_to_collector(collector, donation_code, donor_name, donor_account, donation_amount)
# Out:
# Enter your name: Mahesh
# Enter your bank account: 3306569132644994
# Donation of 100 received for code: 06ffc8ec-feb0-4629-a62b-07b603d9c7c4
# Donor information: 6d8b2ca121ee5ac325e7aaf590ebd0c89ddba4ee702f8bcebad356229257f0b7
# Collector: John Smith
# Collector's Bank Account: XYZ789

# %%
import uuid
import hashlib

# Class to represent a Money Collector
class MoneyCollector:
    def __init__(self, collector_name, bank_account):
        self.collector_name = collector_name
        self.bank_account = bank_account

    def generate_donation_code(self):
        donation_id = str(uuid.uuid4())
        return donation_id


# Class to handle the donation process
class DonationProcessor:
    @staticmethod
    def encrypt_donor_info(donor_name, donor_account):
        # Use a secure encryption algorithm to encrypt the donor information
        encrypted_info = hashlib.sha256((donor_name + donor_account).encode()).hexdigest()
        return encrypted_info

    @staticmethod
    def donate_to_collector(collector, donation_code, donor_name, donor_account, amount, pin):
        # Encrypt the donor information
        encrypted_info = DonationProcessor.encrypt_donor_info(donor_name, donor_account)

        # Verify the PIN number
        if pin != '8218':
            print("Invalid PIN number. Donation not processed.")
            return

        # Simulate the donation process
        # Here, you could send the encrypted donor information and the donation amount to the collector's account
        # This step would involve integrating with a payment gateway or a financial transaction API

        # Print a confirmation message to demonstrate successful donation
        print(f"Donation of {amount} received for code: {donation_code}")
        print(f"Donor information: {encrypted_info}")
        print(f"Collector: {collector.collector_name}")
        print(f"Collector's Bank Account: {collector.bank_account}")


# Example usage
collector_name = "Chandu"
collector_bank_account = "33010191900165"
donation_code = str(uuid.uuid4())

donor_name = input("Enter your name: ")
donor_account = input("Enter your bank account: ")
donation_amount = float(input("Enter the donation amount: "))
pin = input("Enter your PIN: ")

collector = MoneyCollector(collector_name, collector_bank_account)
DonationProcessor.donate_to_collector(collector, donation_code, donor_name, donor_account, donation_amount, pin)
# Out:
# Enter your name: Mahesh
# Enter your bank account: 64464646
# Enter the donation amount: 105444
# Enter your PIN: 8218
# Donation of 105444.0 received for code: 5c8eea7f-0a82-4656-a527-b092928afedc
# Donor information: b826f26e18a4dc988c4da66204a15f4cabdc12dcd0772a5342edfd8dbd63aeae
# Collector: Chandu
# Collector's Bank Account: 33010191900165
